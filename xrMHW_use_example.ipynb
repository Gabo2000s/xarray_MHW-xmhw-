# %%
"""
Simplified Execution Script for Multidimensional Marine Heatwave Detector (xrMHW)
================================================================================
Instructions:
1. Modify the "USER CONFIGURATION" section with your data.
2. Run the script.
3. Open the link that appears in the console to view progress.
"""

import xarray as xr
import numpy as np
from dask.distributed import Client
import sys
import os

# %%
# clone the repository
# !conda install git -y
# !git clone https://github.com/Gabo2000s/xarray_MHW-xrMHW-.git

# %%
repo_folder = r"D:/Articulos/MHW/MHW_Code/xarray_MHW-xrMHW-" ## chose the folder where the repository is cloned
if repo_folder not in sys.path:
    sys.path.append(os.path.abspath(repo_folder))
				
import xrMHW

# %% [markdown]
# **Import and check data variable and dimension names**

# %%
xr.open_dataset(r"E:\MHW_SCC\MHW_Detrended_SCC\OSTIA_SCC_Raw_Cropped.nc")
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:       (time: 15340, latitude: 199, longitude: 160)
# Coordinates:
#   * time          (time) datetime64[ns] 123kB 1982-01-01 ... 2023-12-31
#   * latitude      (latitude) float32 796B 22.08 22.12 22.17 ... 31.92 31.98
#   * longitude     (longitude) float32 640B -118.0 -117.9 ... -110.1 -110.0
# Data variables:
#     analysed_sst  (time, latitude, longitude) float32 2GB ...
# Attributes:
#     source:                    AMSR2-REMSS-L2P-v2.0, AMSRE-REMSS-L2P-v2.0, GO...
#     references:                Donlon, C.J., Martin, M., Stark, J.D., Roberts...
#     comment:                   WARNING Some applications are unable to proper...
#     title:                     Global SST & Sea Ice Analysis, L4 OSTIA, 0.05 ...
#     history:                   Created from sst.nc; obs_anal.nc; seaice.nc
#     Conventions:               CF-1.4, ACDD-1.3
#     institution:               UKMO
#     copernicusmarine_version:  2.2.4

# %% [markdown]
# **Section 1: User Data Configuration**:

# %%
# FILES 
# Full path to the NetCDF file containing your temperature data
INPUT_FILE = r"E:\MHW_SCC\MHW_Detrended_SCC\OSTIA_SCC_Raw_Cropped.nc"

# Path where you want to save the result (must end in .nc)
OUTPUT_FILE = r"E:\MHW_SCC\MHW_Detrended_SCC\OSTIA_SCC_Raw_Cropped_MHW_test.nc"

# DATA 
# Exact name of the temperature variable inside the file (e.g., 'sst', 'analysed_sst')
VAR_NAME = 'analysed_sst'

# CLIMATOLOGY DEFINITION (THE "BASELINE") 
# Base period to calculate the historical average
CLIM_START = 1981
CLIM_END = 2020

# HEATWAVE PARAMETERS 
PERCENTILE = 90    # Threshold (90 is standard for MHW)
MIN_DURATION = 5     # Minimum consecutive days to count as an event
JOIN_GAPS = True  # Join events if interrupted briefly? (Recommended: True)
MAX_GAP_DAYS = 2     # Maximum "non-mhw" days allowed within an event

# PERFORMANCE & CHUNKING
# Number of CPU cores of your computer to use.
NUM_CORES = 10     

# Chunk size controls how data is split to avoid RAM memory overflow. 
# RULE: 'time' MUST be -1 (load all time steps).
# Adjust 'lat'/'lon' (or 'latitude'/'longitude') based on your specific file dimension names.
# Smaller numbers = less RAM usage per core.
CHUNK_CONFIG    = {'time': -1, 'lat': 50, 'lon': 50}

# %% [markdown]
# **Section 2: Automatic Execution (DO NOT EDIT BELOW)**

# %%
if __name__ == "__main__":
    print("\n" + "="*60)
    print(" STARTING MARINE HEATWAVE DETECTOR (xrMHW)")
    print("="*60)

    # 1. Start Dask Client (Parallelism)
    # --------------------------------------------------------------------------
    print(f"... Starting engine with {NUM_CORES} cores.")
    # threads_per_worker=1 avoids conflicts with numerical libraries
    client = Client(n_workers=NUM_CORES, threads_per_worker=1)
    
    print("\n" + "-"*60)
    print(f" >> VIEW PROGRESS BAR HERE:  {client.dashboard_link}")
    print("-"*60 + "\n")

    try:
        # 2. Load Data
        # ----------------------------------------------------------------------
        print(f"... Loading file: {INPUT_FILE}")
        print(f"... Applying chunks: {CHUNK_CONFIG}")
        
        # Open the dataset with user-defined chunks
        # This allows Dask to handle files larger than RAM
        ds = xr.open_dataset(INPUT_FILE, chunks=CHUNK_CONFIG)

        # 3. Run Algorithm (xrMHW)
        # ----------------------------------------------------------------------
        print(f"... Detecting events (Ref: {CLIM_START}-{CLIM_END})...")
        print("    This may take a while depending on file size.")
        
        ds_mhw = xrMHW.xrMHW_func(
            ds, 
            temp_var_name=VAR_NAME, 
            clim_period=(CLIM_START, CLIM_END),
            pctile=PERCENTILE,
            min_duration=MIN_DURATION,
            join_across_gaps=JOIN_GAPS,
            max_gap=MAX_GAP_DAYS
        )

        # 4. Save Results
        # ----------------------------------------------------------------------
        print(f"... Saving results to: {OUTPUT_FILE}")
        
        # Compression configuration to reduce final file size
        comp = {'zlib': True, 'complevel': 5, 'dtype': 'float32', '_FillValue': np.nan}
        encoding = {var: comp for var in ds_mhw.data_vars}
        
        # The .to_netcdf() function triggers the actual calculation in Dask
        ds_mhw.to_netcdf(OUTPUT_FILE, encoding=encoding)
        
        print("\n" + "="*60)
        print(" PROCESS COMPLETED SUCCESSFULLY!")
        print(f" File saved: {OUTPUT_FILE}")
        print("="*60)

    except FileNotFoundError:
        print(f"\n[ERROR] Input file not found: {INPUT_FILE}")
        print("Please check the path in the CONFIGURATION section.")
    except KeyError as e:
        print(f"\n[ERROR] Dimension or Variable mismatch: {e}")
        print(f"Check that VAR_NAME matches the file.")
        print(f"Also check that keys in CHUNK_CONFIG (like 'lat'/'lon') match the dimension names in your file (e.g., maybe they are 'latitude'/'longitude').")
    except Exception as e:
        print(f"\n[UNEXPECTED ERROR] {e}")
    finally:
        # Close the client to free up memory
        client.close()
        print("\nEngine shut down.")
# Out:
# ============================================================
#  STARTING MARINE HEATWAVE DETECTOR (xrMHW)
# ============================================================
# ... Starting engine with 10 cores.
#
# ------------------------------------------------------------
#  >> VIEW PROGRESS BAR HERE:  http://127.0.0.1:8787/status
# ------------------------------------------------------------
#
# ... Loading file: E:\MHW_SCC\MHW_Detrended_SCC\OSTIA_SCC_Raw_Cropped.nc
# ... Applying chunks: {'time': -1, 'lat': 50, 'lon': 50}
# ... Detecting events (Ref: 1981-2020)...
#     This may take a while depending on file size.
# ... Saving results to: E:\MHW_SCC\MHW_Detrended_SCC\OSTIA_SCC_Raw_Cropped_MHW_test.nc
# 2026-01-21 17:18:28,325 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57304 (pid=37108) exceeded 95% memory budget. Restarting...
# 2026-01-21 17:18:28,340 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:57304' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {
- distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:13,365 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:13,439 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:13,568 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:13,658 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:13,841 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:13,859 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:13,957 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,050 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,142 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,357 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,379 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,479 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,550 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,652 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,838 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,874 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:14,950 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:15,050 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:15,144 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:15,360 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:15,452 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:15,554 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:15,648 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:15,839 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:15,916 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:15,942 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:16,049 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:16,158 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57298 (pid=53948) is slow to terminate; trying again
# 2026-01-21 17:20:16,228 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:57298' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('store-map-1c2fb91b8136b3475b050abe596edafd', 3, 4, 0), ('store-map-c62f5882d961909fd3f0fa20de29784d', 2, 4, 0), ('store-map-c62f5882d961909fd3f0fa20de29784d', 4, 2, 0), ('store-map-a5a617c4aeb962cf2525fa656c9b9a52', 2, 4, 0), ('store-map-c62f5882d961909fd3f0fa20de29784d', 4, 4, 0), ('transpose-9ce45164357fe4cda3b6aeaec4438b48', 4, 1, 0), ('vectorize_mhw_1d_wrapper-e30dd94a526a026847eb3ff5a6f5eb59', 0, 2), ('store-map-7c1b7ab7f17355080d641c767c3b117f', 4, 2, 0), ('store-map-8d88241ba85207d557183dc7b73b320b', 4, 2, 0), ('store-map-1c2fb91b8136b3475b050abe596edafd', 0, 2, 0), ('store-map-1c2fb91b8136b3475b050abe596edafd', 4, 4, 0), ('store-map-c62f5882d961909fd3f0fa20de29784d', 0, 2, 0), ('store-map-c62f5882d961909fd3f0fa20de29784d', 0, 4, 0), ('store-map-8d88241ba85207d557183dc7b73b320b', 4, 4, 0), ('store-map-7c1b7ab7f17355080d641c767c3b117f', 0, 4, 0), ('store-map-7c1b7ab7f17355080d641c767c3b117f', 0, 2, 0), ('store-map-a5a617c4aeb962cf2525fa656c9b9a52', 4, 2, 0), ('store-map-8d88241ba85207d557183dc7b73b320b', 0, 2, 0), ('store-map-1c2fb91b8136b3475b050abe596edafd', 0, 4, 0), ('store-map-a5a617c4aeb962cf2525fa656c9b9a52', 4, 4, 0), ('store-map-8d88241ba85207d557183dc7b73b320b', 0, 4, 0), ('store-map-7c1b7ab7f17355080d641c767c3b117f', 2, 4, 0), ('store-map-a5a617c4aeb962cf2525fa656c9b9a52', 0, 2, 0), ('store-map-a5a617c4aeb962cf2525fa656c9b9a52', 0, 4, 0), ('store-map-8d88241ba85207d557183dc7b73b320b', 2, 4, 0)} (stimulus_id='handle-worker-cleanup-1769028616.2252128')
# 2026-01-21 17:20:16,668 - distributed.nanny - WARNING - Restarting worker
# ============================================================
#  PROCESS COMPLETED SUCCESSFULLY!
#  File saved: E:\MHW_SCC\MHW_Detrended_SCC\OSTIA_SCC_Raw_Cropped_MHW_test.nc
# ============================================================
#
# Engine shut down.

# %% [markdown]
# **Exploration of the data**

# %%
ds = xr.open_dataset(r'E:\MHW_SCC\MHW_Detrended_SCC\OSTIA_SCC_Raw_Cropped_MHW_test.nc')

# %%
## plot example of one day (Marine Heatwave Intensity)

ds['mhw_intensity'].sel(time='2014-08-15').plot()

# %%
## plot example of a time series of one point latitude and longitude

ds['mhw_intensity'].sel(latitude=27, longitude=-115, method='nearest').plot()
